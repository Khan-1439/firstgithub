# %% [markdown]
# #Body mass index (BMI)
# #Input
# #Height
# #BMI (Ask your self your height)
# #weight
# #Calculate BMI
# #Print BMI (My name is _________, and my BMI is -----)

# %%
#BMI is weight/height and its squire

# %%
height = input("what is your height? ")
# Out:
# what is your height?  1.68

# %%
height = float(height)

# %%
weight = input ("what is your weight? ")
# Out:
# what is your weight?  68

# %%
weight = float(weight)

# %%
Name = input("what is your name? ")
# Out:
# what is your name?  Fawad

# %%
BMI = weight/height**2
BMI
# Out:
# 24.092970521541954

# %%
print ("My name is", Name, "and my BMI is", BMI)
# Out:
# My name is Fawad and my BMI is 24.092970521541954
