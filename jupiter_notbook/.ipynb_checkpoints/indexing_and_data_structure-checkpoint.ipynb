# %% [markdown]
# **-Indexing**

# %%
#Make a string
a= "Samosa Pakora"
a
# Out:
# 'Samosa Pakora'

# %%
a
# Out:
# 'Samosa Pakora'

# %%
#Length of indeces
len(a)
# Out:
# 13

# %%
a[0]
# Out:
# 'S'

# %%
a[1]
# Out:
# 'a'

# %%
a[3]
# Out:
# 'o'

# %%
a[12]
# Out:
# 'a'

# %%
a[0:5]
# Out:
# 'Samos'

# %%
#last index is exclusive
a[0:13]
# Out:
# 'Samosa Pakora'

# %%
#minus will start from the other side
a[-2]
# Out:
# 'r'

# %%
a[-6:-1]
# Out:
# 'Pakor'

# %%
a[-6:13]
# Out:
# 'Pakora'

# %%
food = "biryani"
food
# Out:
# 'biryani'

# %% [markdown]
# #String methods

# %%
food
# Out:
# 'biryani'

# %%
len(food)
# Out:
# 7

# %%
#capitalize every element
food.capitalize()
# Out:
# 'Biryani'

# %%
#upper case
food.upper()
# Out:
# 'BIRYANI'

# %%
#lower case
food.lower()
# Out:
# 'biryani'

# %%
#replice
food.replace("b", "Sh")
# Out:
# 'Shiryani'

# %%
#counting a specific alphabet in a string
name="fawad_Khan is a nice boy"
name
# Out:
# 'fawad_Khan is a nice boy'

# %%
name.count("a")
# Out:
# 4

# %%
name.count("b")
# Out:
# 1

# %% [markdown]
# #how to find index number in string

# %%
name="fawad_Khan is a nice boy"

# %%
name.find("a")
# Out:
# 1

# %%
name.find("b")
# Out:
# 21

# %%
###how to spilt a strin
food= "I love samosa, pakroa, raita, biryani and karahi"
food
# Out:
# 'I love samosa, pakroa, raita, biryani and karahi'

# %%
food.split(",")
# Out:
# ['I love samosa', ' pakroa', ' raita', ' biryani and karahi']

# %% [markdown]
# #Basic structure of python
#
# 1-Tuple
#
# 2-List
#
# 3-Dictionaries
#
# 4-Set

# %% [markdown]
# ##1-Tuples
#
# -ordered collection of element
#
# -enclosed in () round braces/parenthesis
#
# -different kind of elments can be stored
#
# -once element are stored you can not change them
#
# - Use a tuple when:
#
# -Data should not change
#
# -You want fixed pairs like (x, y)
#
# -You want constant settings

# %%
tup1= (1, "python", True, 2.5)
tup1
# Out:
# (1, 'python', True, 2.5)

# %%
#type of a tuple
type(tup1)
# Out:
# tuple

# %% [markdown]
# #- indexing in tuple

# %%
tup1[1]
# Out:
# 'python'

# %%
tup1[2]
# Out:
# True

# %%
tup1[0:4]
# Out:
# (1, 'python', True, 2.5)

# %%
#last element is exclusive
tup1[0:3]
# Out:
# (1, 'python', True)

# %%
#count of elements in tuple 
len(tup1)
# Out:
# 4

# %%
tup2 = (2, "babaAmmar", 3.5, False)
tup2
# Out:
# (2, 'babaAmmar', 3.5, False)

# %%
#concatinate (to add two tuple or more than two tuple)
tup1 + tup2
# Out:
# (1, 'python', True, 2.5, 2, 'babaAmmar', 3.5, False)

# %%
#concatinate order multiply
tup1*2 + tup2
# Out:
# (1, 'python', True, 2.5, 1, 'python', True, 2.5, 2, 'babaAmmar', 3.5, False)

# %%
tup3 = (20, 50, 30,60,79,85)
tup3
# Out:
# (20, 50, 30, 60, 79, 85)

# %%
#minimum
min(tup3)
# Out:
# 20

# %%
max(tup3)
# Out:
# 85

# %%
tup3*2
# Out:
# (20, 50, 30, 60, 79, 85, 20, 50, 30, 60, 79, 85)

# %% [markdown]
# ---

# %% [markdown]
# ##2- List
#
# -ordered collection of elements
#
# -enclosed in [] square braces/breackets
#
# -can change the values

# %%
list1 = [2, "babaAmmar", False]
list1
# Out:
# [2, 'babaAmmar', False]

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 3

# %%
list1[2]
# Out:
# False

# %%
list2 = [3, 5, "Aammar", "codanics", 478, 53, 2, False]
list2
# Out:
# [3, 5, 'Aammar', 'codanics', 478, 53, 2, False]

# %%
list1 + list2
# Out:
# [2, 'babaAmmar', False, 3, 5, 'Aammar', 'codanics', 478, 53, 2, False]

# %%
list1*2
# Out:
# [2, 'babaAmmar', False, 2, 'babaAmmar', False]

# %%
# after dot press tab so you can see many option
list1.reverse()
list1
# Out:
# [False, 'babaAmmar', 2]

# %%
list1
# Out:
# [2, 'babaAmmar', False]

# %%
list1.append("condanics youtube channel")
list1
# Out:
# [False, 'babaAmmar', 2, 'condanics youtube channel']

# %%
list1.count(2, \)
# Out:
#   Cell In[78], line 1
#     list1.count(2, \)
#                     ^
# SyntaxError: unexpected character after line continuation character

# %%
list3 = [20, 30, 35, 40, 12, 15, 11, 10, 365, 56, 886]
list3
# Out:
# [20, 30, 35, 40, 12, 15, 11, 10, 365, 56, 886]

# %%
len(list3)
# Out:
# 11

# %%
#sorting the list
list3.sort()
list3
# Out:
# [10, 11, 12, 15, 20, 30, 35, 40, 56, 365, 886]

# %%
list3*2
# Out:
# [10,
#  11,
#  12,
#  15,
#  20,
#  30,
#  35,
#  40,
#  56,
#  365,
#  886,
#  10,
#  11,
#  12,
#  15,
#  20,
#  30,
#  35,
#  40,
#  56,
#  365,
#  886]

# %%
list1+list2
# Out:
# [False,
#  'babaAmmar',
#  2,
#  'condanics youtube channel',
#  3,
#  5,
#  'Aammar',
#  'codanics',
#  478,
#  53,
#  2,
#  False]

# %%
lists = list1+list2
lists
# Out:
# [False,
#  'babaAmmar',
#  2,
#  'condanics youtube channel',
#  3,
#  5,
#  'Aammar',
#  'codanics',
#  478,
#  53,
#  2,
#  False]

# %% [markdown]
# ## 3- Dictionaries
#
# -An unordered collection of element
#
# -key and value
#
# -curly braces or brackets {}
#
# -Mutateable or changeableb

# %%
#Food and their prices
food1={"Samosa":30,"Pakora": 100, "Raita":20, "Salad":50, "Chicken rolls":30} # samosa is key and price is values
food1
# Out:
# {'Samosa': 30, 'Pakora': 100, 'Raita': 20, 'Salad': 50, 'Chicken rolls': 30}

# %%
type (food1)
# Out:
# dict

# %%
#extract data
keys1= food1.keys()
keys1
# Out:
# dict_keys(['Samosa', 'Pakora', 'Raita', 'Salad', 'Chicken rolls'])

# %%
values1= food1.values()
values1
# Out:
# dict_values([30, 100, 20, 50, 30])

# %%
#add in the dictionaiers
food1["tikki"]=10
food1
# Out:
# {'Samosa': 30,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken rolls': 30,
#  'tikki': 10}

# %%
#update the values
food1["tikki"]=15
food1
# Out:
# {'Samosa': 30,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken rolls': 30,
#  'tikki': 15}

# %%
food2 = {"Dates":50, "chocolates": 200, "Swayyan": 1000}
food2
# Out:
# {'Dates': 50, 'chocolates': 200, 'Swayyan': 1000}

# %%
#concatinate food1 + food2(), it will give error , so we need to update it
food1.update(food2)

# %%
food1
# Out:
# {'Samosa': 30,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Chicken rolls': 30,
#  'tikki': 15,
#  'Dates': 50,
#  'chocolates': 200,
#  'Swayyan': 1000}

# %% [markdown]
# ##4- Sets
#
# -unordered and unindexed
#
# -curley braces are used{}
#
# -no duplicates allowed

# %%
s1 ={1, 2.2, 2.5, "Aammar", "Codanics", "Faisalabad", True}
s1
# Out:
# {1, 2.2, 2.5, 'Aammar', 'Codanics', 'Faisalabad'}

# %%
s1.add("Aammar1")
s1
# Out:
# {1, 2.2, 2.5, 'Aammar', 'Aammar1', 'Codanics', 'Faisalabad'}

# %%
s1.remove("Aammar")
s1
# Out:
# {1, 2.2, 2.5, 'Aammar1', 'Codanics', 'Faisalabad'}

# %%
tupl.
