# %% [markdown]
# # Learing Python
# ## How to use jupyter note book
# ### Out basics of python
#
# **01- My first program**

# %%
# My_first program in python
print(2+3)
print("hello world")
print("we are lerning python")
print ("Mama_Sareer")
# Out:
# 5
# hello world
# we are lerning python
# Mama_Sareer

# %% [markdown]
# **02- operators**

# %%
print ("2+3") 
print (3-1)
print (6/2)
print (6//2)
print (2*3)
print (13%2)
print(2**3) # raised power 

print(3**2/2*3/3+6-4)
# Out:
# 2+3
# 2
# 3.0
# 3
# 6
# 1
# 8
# 6.5

# %% [markdown]
# *python run your calculation based on PEMDES
# Parentheses, Exponents, Multiplication and Division and substrection
# sequence left to right M D & A S*

# %% [markdown]
# **03-String**
# *what are strings? anything which is used in single , double and triple cautation marks is called strings
# supoose '',"",'''' '''*

# %%
print("hello world")
print("we are lerning python")
print('Test for single quotes')
print("test for double quotes")
print('''test for triple quotes''')
print("what's up")
# Out:
# hello world
# we are lerning python
# Test for single quotes
# test for double quotes
# test for triple quotes
# what's up

# %% [markdown]
# **04- Comments**
#
# *so HESH is for the comments which will not run like: cntrl+/ is shortcut for comments*

# %%
print("how are you?") # print how are you
print ("we are learning python with aammer")
print("2+3")
# Out:
# how are you?
# we are learning python with aammer
# 2+3

# %% [markdown]
# **05-Variables**
#
# *Variables : objects containing specific values*

# %%
x = 5 # numeric or integers variables
print (x)

y="we are learning" # string variables
print (y)
#update the x

x = 10
print (x) # or 

x = x+10
print (x)
# same for the Y,

#types of variables 
type(x)
print(type(x))

print(type(y))

# print_type_class

# Rules to asign a veriables
# 1- The variables should contian letters, nummbers of underscores
# 2- Dont start with nummbers, suppose in upper case 2y or 2x
# 3 Spaces are not allowed
# 4- dont use keywords in functions(break, mean, median, test etc)
# 5- Short and descriptive 
# 6- case senstivity (lowercase, uppercase, lowercase should be used)

fruit_basket= "Mangoes, oranges"
print(fruit_basket)
fruit_basket= 8
print(fruit_basket)
print(type(fruit_basket))

# delet furit basket
del fruit_basket # will not work because we named it 8 and mangoes , oranges, so its not defined
# Out:
# 5
# we are learning
# 10
# 20
# <class 'int'>
# <class 'str'>
# Mangoes, oranges
# 8
# <class 'int'>
